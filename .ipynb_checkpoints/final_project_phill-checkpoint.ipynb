# %% [markdown]
# # Final Project Template

# %% [markdown]
# ## 1) Get your data
# You may use any data set(s) you like, so long as they meet these criteria:
#
# * Your data must be publically available for free.
# * Your data should be interesting to _you_. You want your final project to be something you're proud of.
# * Your data should be "big enough":
#     - It should have at least 1,000 rows.
#     - It should have enough of columns to be interesting.
#     - If you have questions, contact a member of the instructional team.

# %% [markdown]
# ## 2) Provide a link to your data
# Your data is required to be free and open to anyone.
# As such, you should have a URL which anyone can use to download your data:

# %%
#Sephora Products: https://www.kaggle.com/raghadalharbi/all-products-available-on-sephora-website/download

# %% [markdown]
# ## 3) Import your data
# In the space below, import your data.
# If your data span multiple files, read them all in.
# If applicable, merge or append them as needed.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# set the plots to display in the Jupyter notebook
# %matplotlib inline

# change plotting colors per client request
plt.style.use('ggplot')

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
#!ls for Linux
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is E29E-709E
#
#  Directory of C:\Users\phill\DCPYTH4
#
# 04/30/2020  05:24 PM    <DIR>          .
# 04/30/2020  05:24 PM    <DIR>          ..
# 04/29/2020  12:28 PM    <DIR>          .ipynb_checkpoints
# 04/28/2020  07:41 PM         1,989,197 avocado.csv
# 04/30/2020  05:24 PM           164,258 final_project_template.ipynb
# 04/28/2020  07:53 PM           127,723 flavors_of_cacao.csv
# 04/29/2020  12:28 PM         2,957,809 international_football_results.csv
# 04/07/2020  08:46 PM            10,829 Moduels_practice.ipynb
# 04/29/2020  07:54 PM           417,896 pandas_plotting.ipynb
# 04/29/2020  08:14 AM             2,915 pandas_practice.ipynb
# 04/29/2020  08:37 AM    <DIR>          python-programming
# 04/29/2020  11:26 AM        23,224,852 sephora_data.csv
#                8 File(s)     28,895,479 bytes
#                4 Dir(s)   9,047,224,320 bytes free

# %%
sephora_products = pd.read_csv('./sephora_data.csv')

# %% [markdown]
# ## 4) Show me the head of your data.

# %%
sephora_products.head(3)
# Out:
#         id           brand   category                            name  \
# 0  2218774  Acqua Di Parma  Fragrance  Blu Mediterraneo MINIATURE Set
# 1  2044816  Acqua Di Parma    Cologne                         Colonia
# 2  1417567  Acqua Di Parma    Perfume                Arancia di Capri
#
#              size  rating  number_of_reviews  love  price  value_price  ...  \
# 0  5 x 0.16oz/5mL     4.0                  4  3002   66.0         75.0  ...
# 1   0.7 oz/ 20 mL     4.5                 76  2700   66.0         66.0  ...
# 2    5 oz/ 148 mL     4.5                 26  2600  180.0        180.0  ...
#
#   MarketingFlags  MarketingFlags_content  \
# 0           True             online only
# 1           True             online only
# 2           True             online only
#
#                                              options  \
# 0                                         no options
# 1   - 0.7 oz/ 20 mL  Spray  - 1.7 oz/ 50 mL Eau d...
# ...

# %% [markdown]
# Note: "Love" is Sephora's terminalogy for saving an item for easy access.

# %%
sephora_products.dtypes
# Out:
# id                          int64
# brand                      object
# category                   object
# name                       object
# size                       object
# rating                    float64
# number_of_reviews           int64
# love                        int64
# price                     float64
# value_price               float64
# URL                        object
# MarketingFlags               bool
# MarketingFlags_content     object
# options                    object
# details                    object
# how_to_use                 object
# ingredients                object
# online_only                 int64
# exclusive                   int64
# limited_edition             int64
# limited_time_offer          int64
# dtype: object

# %%
sephora_categories = sephora_products['category'].unique()

# %%
#Calculating and defining what portion of the categories in Sephora make up 10% of the available products
num_categories_top_10_percent = len(sephora_categories)//10
num_categories_top_10_percent
# Out:
# 14

# %%
sephora_products['category'].value_counts().head(num_categories_top_10_percent)
# Out:
# Perfume                      665
# Moisturizers                 451
# Face Serums                  384
# Value & Gift Sets            378
# Face Wash & Cleansers        247
# Face Masks                   230
# Rollerballs & Travel Size    228
# Hair Styling Products        224
# Eye Palettes                 202
# Lipstick                     191
# Eye Creams & Treatments      191
# Shampoo                      186
# Face Brushes                 183
# Highlighter                  169
# Name: category, dtype: int64

# %% [markdown]
# The top 10% of types of products sold through Sephora

# %%
sephora_products['category'].value_counts().head(num_categories_top_10_percent).plot.barh();

# %%
list_categories_top_10_percent = ["Perfume",
                             "Moisturizers",
                             "Face_Serums",
                             "Value_Gift_Sets",
                             "Face_Wash_Cleansers",
                             "Face_Masks",
                             "Rollerballs_Travel_Size",
                             "Hair_Styling_Products",
                             "Eye_Palettes",
                             "Lipstick",
                             "Eye_Creams_Treatments",
                             "Shampoo",
                             "Face_Brushes",
                             "Highlighter"]
list_categories_top_10_percent
# Out:
# ['Perfume',
#  'Moisturizers',
#  'Face_Serums',
#  'Value_Gift_Sets',
#  'Face_Wash_Cleansers',
#  'Face_Masks',
#  'Rollerballs_Travel_Size',
#  'Hair_Styling_Products',
#  'Eye_Palettes',
#  'Lipstick',
#  'Eye_Creams_Treatments',
#  'Shampoo',
#  'Face_Brushes',
#  'Highlighter']

# %%
categories_top_10_percent = sephora_products[sephora_products.category.isin(list_categories_top_10_percent)]

# %%
#Creating Series to filter using isin
Perfume = ["Perfume"]
Moisturizers = ["Moisturizers"]
Face_Serums = ["Face_Serums"]
Value_Gift_Sets = ["Value_Gift_Sets"]
Face_Wash_Cleansers = ["Face_Wash_Cleansers"]
Face_Masks = ["Face_Masks"]
Rollerballs_Travel_Size = ["Rollerballs_Travel_Size"]
Hair_Styling_Products = ["Hair_Styling_Products"]
Eye_Palettes = ["Eye_Palettes"]
Lipstick = ["Lipstick"]
Eye_Creams_Treatments = ["Eye_Creams_Treatments"]
Shampoo = ["Shampoo"]
Face_Brushes = ["Face_Brushes"]
Highlighter = ["Highlighter"]

# %%
#Creating DataFrames for the most common categories at Sephora
Face_Serums = sephora_products[sephora_products.category.isin(Face_Serums)]
Value_Gift_Sets = sephora_products[sephora_products.category.isin(Value_Gift_Sets)]
Face_Wash_Cleansers = sephora_products[sephora_products.category.isin(Face_Wash_Cleansers)]
Face_Masks = sephora_products[sephora_products.category.isin(Face_Masks)]
Rollerballs_Travel_Size = sephora_products[sephora_products.category.isin(Rollerballs_Travel_Size)]
Hair_Styling_Products = sephora_products[sephora_products.category.isin(Hair_Styling_Products)]
Eye_Palettes = sephora_products[sephora_products.category.isin(Eye_Palettes)]
Lipstick = sephora_products[sephora_products.category.isin(Lipstick)]
Eye_Creams_Treatments = sephora_products[sephora_products.category.isin(Eye_Creams_Treatments)]
Shampoo = sephora_products[sephora_products.category.isin(Shampoo)]
Face_Brushes = sephora_products[sephora_products.category.isin(Face_Brushes)]
Highlighter = sephora_products[sephora_products.category.isin(Highlighter)]

# %% [markdown]
# ## 5) Show me the shape of your data

# %%
sephora_products['rating'].plot.hist(bins=20)
plt.ylabel('Number of Ratings')
plt.xlabel('Product Ratings')
plt.title('Number of Ratings x Product Rating');

# %%
sephora_products.plot.scatter(
    x='price', y='rating',
    color='mediumvioletred', 
    figsize=(22,5), s=10, alpha=0.5
)
plt.title('All Products Rating x Price');

# %%
categories_top_10_percent['rating'].plot.hist(bins=20)
plt.ylabel('Number of Ratings')
plt.xlabel('Product Ratings')
plt.title('Top Products Number of Ratings x Product Rating');

# %%
categories_top_10_percent.plot.scatter(
    x='price', y='rating',
    color='mediumvioletred', 
    figsize=(22,5), s=10, alpha=0.5
)
plt.title('Top Products Rating x Price');

# %% [markdown]
# ## 6) Show me the proportion of missing observations for each column of your data

# %%
sephora_products.isna().sum()
# Out:
# id                        0
# brand                     0
# category                  0
# name                      0
# size                      0
# rating                    0
# number_of_reviews         0
# love                      0
# price                     0
# value_price               0
# URL                       0
# MarketingFlags            0
# MarketingFlags_content    0
# options                   0
# details                   0
# how_to_use                0
# ingredients               0
# online_only               0
# exclusive                 0
# limited_edition           0
# limited_time_offer        0
# dtype: int64

# %% [markdown]
# ## 7) Give me a problem statement.
# Below, write a problem statement. Keep in mind that your task is to tease out relationships in your data and eventually build a predictive model. Your problem statement can be vague, but you should have a goal in mind. Your problem statement should be between one sentence and one paragraph.

# %% [markdown]
# What level of impact do beauty trends hold on retail stock?
#
# Knowing the impact of these trends would require a comparison of the trends to the proportions of products available over time. Getting these numbers would require further scrapping of the Sephora website, as well as, beauty trend forecasts.

# %% [markdown]
# ## 8) What is your _y_-variable?
# For final project, you will need to perform a statistical model. This means you will have to accurately predict some y-variable for some combination of x-variables. From your problem statement in part 7, what is that y-variable?
